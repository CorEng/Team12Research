# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import pickle

# %%
modelframe = pd.read_csv("cleaned145dist.csv")

# %%
modelframe
# Out:
#          Unnamed: 0  Unnamed: 0.1                 time  duration  Holiday  \
# 0                 0             2  2018-01-01 08:00:00        51        1
# 1                 1             3  2018-01-01 08:00:00        47        1
# 2                 2             4  2018-01-01 08:00:00        59        1
# 3                 3             5  2018-01-01 08:00:00        98        1
# 4                 4             6  2018-01-01 08:00:00        40        1
# 5                 5             7  2018-01-01 08:00:00        30        1
# 6                 6             8  2018-01-01 08:00:00        36        1
# 7                 7             9  2018-01-01 08:00:00        11        1
# 8                 8            10  2018-01-01 08:00:00        21        1
# 9                 9            11  2018-01-01 08:00:00        42        1
# 10               10            12  2018-01-01 08:00:00        58        1
# 11               11            13  2018-01-01 08:00:00        44        1
# ...

# %%
clf= pickle.load(open("pickle_model2.pkl", 'rb'))

# %%
clf.predict([[0,20000,0.01,8.19,0.97,21600.0]])
# Out:
# array([49.10000001])
